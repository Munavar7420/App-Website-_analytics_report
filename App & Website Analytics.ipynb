# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install plotly
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
data = "E:\Masai Course(Data Anaytics)\Project\promlio assignment\App Analytics Report-06.05.2023.xlsx"

# %%
df = pd.read_excel(data, sheet_name=None)

# %%
df1 = df['User Acquisition']
df2 = df['Traffic Aquisition']
df3 = df['Event Report']
df4 = df['Conversion Report']
df5 = df['Pages & Screens Report']
df6 = df['Demographics Report']
df7 = df['Citiwise Report']
df8 = df['Gender Report']
df9 = df['User By Interest']
df10 = df['User by Language']
df11 = df['User By Age']
df12 = df['Google Ads Report']

# %%
df1
# Out:
#   First user default channel group  New users  Engaged sessions  \
# 0                          Display       9957             12008
# 1                   Organic Search       7652             18141
# 2                      Paid Search       3025              4408
# 3                           Direct       1903              4975
# 4                       Unassigned        325              1619
# 5                   Organic Social         10                13
#
#    Engagement rate  Engaged sessions per user  Average engagement time  \
# 0         0.544457                   1.206107                 58.86209
# 1         0.813680                   2.367041                534.31280
# 2         0.474284                   1.458154                102.23780
# 3         0.318808                   2.261364               1128.88100
# 4         0.813159                   4.981538                798.34150
# 5         0.722222                   1.300000                145.30000
#
# ...

# %%
df1.shape
# Out:
# (6, 9)

# %%
df2
# Out:
#   Session default channel group  Users  Sessions  Engaged sessions  \
# 0                    Unassigned  20263     13448              1481
# 1                       Display   9613     18292             10613
# 2                Organic Search   7689     21241             17814
# 3                        Direct   4042     13220              7649
# 4                   Paid Search   2909      6788              3452
# 5                Organic Social     11        16                12
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                             34.11704                   0.073089
# 1                             28.52198                   1.104026
# 2                            195.94340                   2.316816
# 3                            177.17060                   1.892380
# 4                             36.65321                   1.186662
# 5                             60.06250                   1.090909
#
# ...

# %%
df2.shape
# Out:
# (6, 11)

# %%
df3.head()
# Out:
#              Event name  Event count  Total users  Event count per user  \
# 0           screen_view       694729        23254             30.865870
# 1  notification_receive       125146         1700            138.896800
# 2       user_engagement       124836        22699              5.622230
# 3  notification_dismiss        70128         1369            144.000000
# 4         session_start        61163        23226              3.121357
#
#    Total revenue
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df3.shape
# Out:
# (379, 5)

# %%
df4.head()
# Out:
#               Event name  Conversions  Total users  Total revenue
# 0   notification_receive        94890         1311              0
# 1          session_start        56203        21674              0
# 2             first_open        22872        23059              0
# 3             app_remove        12468        12538              0
# 4  Promilo111_otp_screen         1738          855              0

# %%
df4.shape
# Out:
# (18, 4)

# %%
df5.head()
# Out:
#   Page path and screen class   Views  Users  Views per user  \
# 0                    Flutter  156708   8726       17.958740
# 1               MainActivity   44326   8978        4.937180
# 2                      feeds   18514   4358        4.248279
# 3                      login   16883   7291        2.315595
# 4          my_rewards_screen   15381   2045        7.521271
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                 83.41222       203901          328              0
# 1                 78.29216        53374          101              0
# 2                 61.60005        37628          253              0
# 3                 34.88177        40772          435              0
# 4                 94.17995        32910            5              0

# %%
df5.shape
# Out:
# (42, 8)

# %%
df6.head()
# Out:
#           Country  Users  New users  Engaged sessions  Engagement rate  \
# 0           India  23024      22528             41479         0.593626
# 1   United States    272        213               197         0.491272
# 2          Canada     37         18                25         0.416667
# 3       (not set)     36         36                17         0.459459
# 4  United Kingdom     20          8                13         0.371429
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.801555                334.81660      1312097
# 1                   0.724265                 50.96324         3157
# 2                   0.675676                 43.21622          410
# 3                   0.472222                 24.80556          241
# 4                   0.650000                 61.85000          289
#
#    Conversions  Total revenue
# 0       192766              0
# 1          643              0
# 2          121              0
# ...

# %%
df6.shape
# Out:
# (47, 10)

# %%
df7.head()
# Out:
#    Town/City  Users  New users  Engaged sessions  Engagement rate  \
# 0  Bengaluru   6097       5685             15013         0.769385
# 1      Patna   1594       1467              2127         0.440646
# 2  Hyderabad   1038        920              1578         0.569264
# 3     Indore    983        915              1241         0.426460
# 4    Lucknow    897        839              1125         0.450180
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   2.462359                762.20550       607200
# 1                   1.334379                 98.22208        38830
# 2                   1.520231                243.69080        96826
# 3                   1.262462                 67.89115        21383
# 4                   1.254181                 83.40580        21041
#
#    Conversions  Total revenue
# 0        62939              0
# 1         6980              0
# 2        34103              0
# 3         4121              0
# ...

# %%
df7.shape
# Out:
# (574, 10)

# %%
df8.head()
# Out:
#     Gender  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  13142      12691             23161         0.564077
# 1     male   7218       5877             10467         0.543091
# 2   female   4944       4304              7877         0.637710
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.762365                 439.5776       761771
# 1                   1.450125                 128.2319       282504
# 2                   1.593244                 208.7407       274254
#
#    Conversions  Total revenue
# 0        93180              0
# 1        65651              0
# 2        35083              0

# %%
df8.shape
# Out:
# (3, 10)

# %%
df9.head()
# Out:
#                                        Interests  Users  New users  \
# 0                                       Shoppers  10950       9256
# 1  Media & Entertainment/Comics & Animation Fans  10946       9247
# 2                  Technology/Mobile Enthusiasts  10934       9239
# 3              Food & Dining/Cooking Enthusiasts   8410       6970
# 4        Sports & Fitness/Health & Fitness Buffs   5844       4580
#
#    Engaged sessions  Engagement rate  Engaged sessions per user  \
# 0             15652         0.581534                   1.429406
# 1             15680         0.583008                   1.432487
# 2             15619         0.582451                   1.428480
# 3             12332         0.602325                   1.466350
# 4              8226         0.588328                   1.407598
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                 162.8347       490664        86846              0
# ...

# %%
df9.shape
# Out:
# (89, 10)

# %%
df10.head()
# Out:
#    Language  Users  New users  Engaged sessions  Engagement rate  \
# 0   English  22495      21990             40639         0.595147
# 1     Hindi    586        552               798         0.406314
# 2   Marathi     85         84                98         0.426087
# 3  Gujarati     78         77               100         0.448430
# 4    Telugu     43         42                56         0.455285
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.806579                341.36350      1297970
# 1                   1.361775                 60.03413        13523
# 2                   1.152941                 38.48235         1589
# 3                   1.282051                 46.53846         1794
# 4                   1.302326                 36.65116          812
#
#    Conversions  Total revenue
# 0       189946              0
# 1         2699              0
# 2          323              0
# 3          327              0
# ...

# %%
df10.shape
# Out:
# (24, 10)

# %%
df11.head()
# Out:
#        Age  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  14303      13636             24976         0.569098
# 1    18-24   4282       3678              7291         0.695308
# 2    25-34   2920       2161              3749         0.504780
# 3      65+   1422       1081              1640         0.539829
# 4    55-64   1403        979              1552         0.519411
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.746207                422.22330       817501
# 1                   1.702709                251.16300       309328
# 2                   1.283904                 97.24144        90074
# 3                   1.153305                 52.30661        24780
# 4                   1.106201                 55.37063        25169
#
#    Conversions  Total revenue
# 0        99310              0
# 1        53661              0
# 2        20172              0
# 3         4891              0
# ...

# %%
df11.shape
# Out:
# (7, 10)

# %%
df12.head()
# Out:
#                Session Google Ads campaign  Users  Sessions  Engaged sessions  \
# 0        App Installation for May --Shahid   5429     10936              6276
# 1      App Install-States-A200Inst-20Jun22    842      1655               968
# 2  App Install-States-B100Installs-22Jun22    742      1332               780
# 3          App Install for April -- Shahid    473       976               546
# 4  Video-AppInstall-PS-Internships-11Jul22    510       966               515
#
#    Google Ads clicks  Google Ads cost  Google Ads cost per click  Conversions  \
# 0             147100       179175.000                   1.218049        12257
# 1              28742        24309.130                   0.845770         1794
# 2              17809        22374.580                   1.256363         1422
# 3              19302        20525.180                   1.063370         1115
# 4               9831         6377.833                   0.648747         1032
#
# ...

# %%
df12.shape
# Out:
# (15, 12)

# %% [markdown]
# ### User Acquisition

# %%
df1.head()
# Out:
#   First user default channel group  New users  Engaged sessions  \
# 0                          Display       9957             12008
# 1                   Organic Search       7652             18141
# 2                      Paid Search       3025              4408
# 3                           Direct       1903              4975
# 4                       Unassigned        325              1619
#
#    Engagement rate  Engaged sessions per user  Average engagement time  \
# 0         0.544457                   1.206107                 58.86209
# 1         0.813680                   2.367041                534.31280
# 2         0.474284                   1.458154                102.23780
# 3         0.318808                   2.261364               1128.88100
# 4         0.813159                   4.981538                798.34150
#
#    Event count  Conversions  Total revenue
# 0       204820        37434              0
# 1       770710       109801              0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   First user default channel group  6 non-null      object
#  1   New users                         6 non-null      int64
#  2   Engaged sessions                  6 non-null      int64
#  3   Engagement rate                   6 non-null      float64
#  4   Engaged sessions per user         6 non-null      float64
#  5   Average engagement time           6 non-null      float64
#  6   Event count                       6 non-null      int64
#  7   Conversions                       6 non-null      int64
#  8   Total revenue                     6 non-null      int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 560.0+ bytes

# %%
df1.isnull().sum()
# Out:
# First user default channel group    0
# New users                           0
# Engaged sessions                    0
# Engagement rate                     0
# Engaged sessions per user           0
# Average engagement time             0
# Event count                         0
# Conversions                         0
# Total revenue                       0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.describe()
# Out:
#          New users  Engaged sessions  Engagement rate  \
# count     6.000000          6.000000         6.000000
# mean   3812.000000       6860.666667         0.614435
# std    4083.739659       6894.604867         0.201367
# min      10.000000         13.000000         0.318808
# 25%     719.500000       2316.250000         0.491827
# 50%    2464.000000       4691.500000         0.633339
# 75%    6495.250000      10249.750000         0.790425
# max    9957.000000      18141.000000         0.813680
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   6.000000                 6.000000       6.000000
# mean                    2.262367               461.322532  219754.833333
# std                     1.420806               437.111008  284869.104021
# min                     1.206107                58.862090     248.000000
# 25%                     1.339538               113.003350   45489.250000
# ...

# %%
numerical_columns = ['New users', 'Engaged sessions', 'Engagement rate', 'Engaged sessions per user',
                     'Average engagement time', 'Event count', 'Conversions']

for column in numerical_columns:
    plt.hist(df1[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df1[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df1.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
new_user_acq = go.Pie(labels=df1["First user default channel group"],
                     values=df1["New users"],
                     marker=dict(colors=["teal","navy","orange","DarkSeaGreen","purple","DarkSlateGray"]),
                     textinfo='label+percent',
                     textposition='outside',
                     hoverinfo='label+percent',
                     hole=0.4)
layout = go.Layout(title='New User Acquisition')

fig = go.Figure(data=[new_user_acq], layout=layout)
fig.show()
# Out:
# <div>                            <div id="26487dfb-3159-477c-98f4-9411d74d18f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26487dfb-3159-477c-98f4-9411d74d18f3")) {                    Plotly.newPlot(                        "26487dfb-3159-477c-98f4-9411d74d18f3",                        [{"hole":0.4,"hoverinfo":"label+percent","labels":["Display","Organic Search","Paid Search","Direct","Unassigned","Organic Social"],"marker":{"colors":["teal","navy","orange","DarkSeaGreen","purple","DarkSlateGray"]},"textinfo":"label+percent","textposition":"outside","values":[9957,7652,3025,1903,325,10],"type":"pie"}],                        {"title":{"text":"New User Acquisition"},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a
# ...

# %% [markdown]
# ### Traffic Aquisition

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Session default channel group        6 non-null      object
#  1   Users                                6 non-null      int64
#  2   Sessions                             6 non-null      int64
#  3   Engaged sessions                     6 non-null      int64
#  4   Average engagement time per session  6 non-null      float64
#  5   Engaged sessions per user            6 non-null      float64
#  6   Events per session                   6 non-null      float64
#  7   Engagement rate                      6 non-null      float64
#  8   Event count                          6 non-null      int64
#  9   Conversions                          6 non-null      int64
#  10  Total revenue                        6 non-null      int64
# ...

# %%
df2.isnull().sum()
# Out:
# Session default channel group          0
# Users                                  0
# Sessions                               0
# Engaged sessions                       0
# Average engagement time per session    0
# Engaged sessions per user              0
# Events per session                     0
# Engagement rate                        0
# Event count                            0
# Conversions                            0
# Total revenue                          0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe()
# Out:
#               Users      Sessions  Engaged sessions  \
# count      6.000000      6.000000          6.000000
# mean    7421.166667  12167.500000       6836.833333
# std     7162.088199   7735.416104       6665.397735
# min       11.000000     16.000000         12.000000
# 25%     3192.250000   8396.000000       1973.750000
# 50%     5865.500000  13334.000000       5550.500000
# 75%     9132.000000  17081.000000       9872.000000
# max    20263.000000  21241.000000      17814.000000
#
#        Average engagement time per session  Engaged sessions per user  \
# count                             6.000000                   6.000000
# mean                             88.744788                   1.277314
# std                              76.756564                   0.772272
# min                              28.521980                   0.073089
# 25%                              34.751083                   1.094188
# 50%                              48.357855                   1.145344
# ...

# %%
numerical_columns = ['Users', 'Sessions', 'Engaged sessions', 'Average engagement time per session',
                     'Engaged sessions per user', 'Events per session', 'Engagement rate',
                     'Event count', 'Conversions']
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df2[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df2[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df2.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
traffic_pie = go.Pie(labels=df2["Session default channel group"],
                     values=df5["Users"],
                     marker=dict(colors=["teal","navy","purple","DarkSeaGreen","orange","DarkSlateGray"]),
                     textinfo='label+percent',
                     textposition='outside',
                     hoverinfo='label+percent',
                     hole=0.4)
layout = go.Layout(title='Traffic percentile')

fig = go.Figure(data=[traffic_pie], layout=layout)
fig.show()
# Out:
# <div>                            <div id="97ecbdaf-ae94-4f7d-9422-a1bdcfbbcd15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97ecbdaf-ae94-4f7d-9422-a1bdcfbbcd15")) {                    Plotly.newPlot(                        "97ecbdaf-ae94-4f7d-9422-a1bdcfbbcd15",                        [{"hole":0.4,"hoverinfo":"label+percent","labels":["Unassigned","Display","Organic Search","Direct","Paid Search","Organic Social"],"marker":{"colors":["teal","navy","purple","DarkSeaGreen","orange","DarkSlateGray"]},"textinfo":"label+percent","textposition":"outside","values":[8726,8978,4358,7291,2045,5244,3778,3566,1047,1678,1521,675,828,193,648,411,600,490,722,321,155,273,375,225,281,58,151,18,17,73,45,23,24,21,3,12,10,4,3,2,2,9145],"type":"pie"}],             
# ...

# %% [markdown]
# ### Event Report

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Event name            378 non-null    object
#  1   Event count           379 non-null    int64
#  2   Total users           379 non-null    int64
#  3   Event count per user  379 non-null    float64
#  4   Total revenue         379 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.9+ KB

# %%
df3.isnull().sum()
# Out:
# Event name              1
# Event count             0
# Total users             0
# Event count per user    0
# Total revenue           0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.describe()
# Out:
#          Event count   Total users  Event count per user  Total revenue
# count     379.000000    379.000000            379.000000          379.0
# mean     3478.968338    583.583113              3.220647            0.0
# std     37073.635167   2791.449046             10.403279            0.0
# min         0.000000      1.000000              0.000000            0.0
# 25%         7.000000      3.500000              1.252451            0.0
# 50%        63.000000     31.000000              1.750000            0.0
# 75%       503.500000    238.000000              2.793359            0.0
# max    694729.000000  23254.000000            144.000000            0.0

# %%
numerical_columns = ['Event count', 'Total users', 'Event count per user']

for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df3[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df3[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df3.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Conversion Report

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Event name     18 non-null     object
#  1   Conversions    18 non-null     int64
#  2   Total users    18 non-null     int64
#  3   Total revenue  18 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 704.0+ bytes

# %%
df4.isnull().sum()
# Out:
# Event name       0
# Conversions      0
# Total users      0
# Total revenue    0
# dtype: int64

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df4.describe()
# Out:
#         Conversions   Total users  Total revenue
# count     18.000000     18.000000           18.0
# mean   10773.000000   3468.777778            0.0
# std    25160.036433   7461.269980            0.0
# min       20.000000     10.000000            0.0
# 25%      127.250000     33.750000            0.0
# 50%      620.500000    246.500000            0.0
# 75%     1702.000000    940.500000            0.0
# max    94890.000000  23059.000000            0.0

# %%
correlation_matrix = df4.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Page and report

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Page path and screen class  42 non-null     object
#  1   Views                       42 non-null     int64
#  2   Users                       42 non-null     int64
#  3   Views per user              42 non-null     float64
#  4   Average engagement time     42 non-null     float64
#  5   Event count                 42 non-null     int64
#  6   Conversions                 42 non-null     int64
#  7   Total revenue               42 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.8+ KB

# %%
df5.isnull().sum()
# Out:
# Page path and screen class    0
# Views                         0
# Users                         0
# Views per user                0
# Average engagement time       0
# Event count                   0
# Conversions                   0
# Total revenue                 0
# dtype: int64

# %%
df5.duplicated().sum()
# Out:
# 0

# %%
df5.describe()
# Out:
#                Views        Users  Views per user  Average engagement time  \
# count      42.000000    42.000000       42.000000                42.000000
# mean     7081.261905  1524.761905        3.036123                48.898515
# std     24926.556037  2628.069168        3.001363                58.750556
# min         0.000000     2.000000        0.000000                 0.001093
# 25%        69.250000    23.250000        1.510656                 9.340753
# 50%       736.500000   301.000000        1.864079                35.592545
# 75%      2734.750000  1402.500000        3.696037                67.387118
# max    156708.000000  9145.000000       17.958740               304.333300
#
#          Event count   Conversions  Total revenue
# count      42.000000     42.000000           42.0
# mean    13417.547619   2145.690476            0.0
# std     36182.217422  13652.911458            0.0
# min         4.000000      0.000000            0.0
# ...

# %%
numerical_columns = ['Views','Users','Views per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df5[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df5[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df5.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
pages_and_screens_report_sort = df5.sort_values(by="Views",ascending=False)
top10_pages_and_screens=pages_and_screens_report_sort.head(10)
top10_pages_and_screens

bar1=go.Bar(x=top10_pages_and_screens["Page path and screen class"],
            y=top10_pages_and_screens["Views"],
            text=top10_pages_and_screens["Views"],
            textposition="auto",
            name="Views",
            marker=dict(color="teal"))

layout = go.Layout(title="Top 10 pages and screens by views", height=600,
                   xaxis=dict(title='pages path and screen'),
                   yaxis=dict(title='Number of views'))
fig=go.Figure(data=[bar1],layout=layout)

fig.show()
# Out:
# <div>                            <div id="a8ad674a-3686-4a8e-b753-203ea7c1c8e2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8ad674a-3686-4a8e-b753-203ea7c1c8e2")) {                    Plotly.newPlot(                        "a8ad674a-3686-4a8e-b753-203ea7c1c8e2",                        [{"marker":{"color":"teal"},"name":"Views","text":[156708.0,44326.0,18514.0,16883.0,15381.0,8189.0,6650.0,5501.0,3971.0,3291.0],"textposition":"auto","x":["Flutter","MainActivity","feeds","login","my_rewards_screen","storyboard","SignInHubActivity","registration_screen","feedDetails","otp_screen"],"y":[156708,44326,18514,16883,15381,8189,6650,5501,3971,3291],"type":"bar"}],                        {"height":600,"title":{"text":"Top 10 pages and screens by views"},"
# ...

# %%
pages_and_screens_report_sort = df5.sort_values(by="Views",ascending=True)
below10_pages_and_screens=pages_and_screens_report_sort.head(10)
below10_pages_and_screens

bar1=go.Bar(x=below10_pages_and_screens["Page path and screen class"],
            y=below10_pages_and_screens["Views"],
            text=below10_pages_and_screens["Views"],
            textposition="auto",
            name="Views",
            marker=dict(color="teal"))

layout = go.Layout(title="below 10 pages and screens by views", height=600,
                   xaxis=dict(title='pages path and screen'),
                   yaxis=dict(title='Number of views'))
fig=go.Figure(data=[bar1],layout=layout)

fig.show()
# Out:
# <div>                            <div id="91ee27f2-3f58-4b9d-ac79-8e8cf1903a1c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91ee27f2-3f58-4b9d-ac79-8e8cf1903a1c")) {                    Plotly.newPlot(                        "91ee27f2-3f58-4b9d-ac79-8e8cf1903a1c",                        [{"marker":{"color":"teal"},"name":"Views","text":[0.0,2.0,2.0,4.0,6.0,13.0,20.0,24.0,34.0,35.0],"textposition":"auto","x":["(not set)","UIAlertController","CAMImagePickerCameraViewController","campaign_meeting","SLComposeViewController","PHPickerViewController","my_profile_others","CheckoutActivity","SFSafariViewController","CustomTabActivity"],"y":[0,2,2,4,6,13,20,24,34,35],"type":"bar"}],                        {"height":600,"title":{"text":"below 10 pages and 
# ...

# %% [markdown]
# ### Demographic report

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    47 non-null     object
#  1   Users                      47 non-null     int64
#  2   New users                  47 non-null     int64
#  3   Engaged sessions           47 non-null     int64
#  4   Engagement rate            47 non-null     float64
#  5   Engaged sessions per user  47 non-null     float64
#  6   Average engagement time    47 non-null     float64
#  7   Event count                47 non-null     int64
#  8   Conversions                47 non-null     int64
#  9   Total revenue              47 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 3.8+ KB

# %%
df6.isnull().sum()
# Out:
# Country                      0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df6.duplicated().sum()
# Out:
# 0

# %%
df6.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count     47.000000     47.000000         47.000000        47.000000
# mean     500.148936    486.638298        890.340426         0.561662
# std     3357.099816   3285.103773       6049.238031         0.358970
# min        0.000000      0.000000          0.000000         0.000000
# 25%        1.000000      0.000000          1.000000         0.364286
# 50%        2.000000      1.000000          1.000000         0.533333
# 75%        7.000000      3.000000          6.000000         1.000000
# max    23024.000000  22528.000000      41479.000000         1.000000
#
#        Engaged sessions per user  Average engagement time   Event count  \
# count                  47.000000                47.000000  4.700000e+01
# mean                    0.835367                48.376626  2.805381e+04
# std                     0.568228                93.511799  1.913692e+05
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df6[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df6[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df6.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
demographic_sort=df6.sort_values(by=["Users","New users"],ascending=False)
top10_demographic=df6.head(10)
top10_demographic

bar1=go.Bar(x=top10_demographic["Country"],
            y=top10_demographic["Users"],
            text=top10_demographic["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))


bar2=go.Bar(x=top10_demographic["Country"],
            y=top10_demographic["New users"],
            text=top10_demographic["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="navy"))

layout = go.Layout(title="Top 10 country who install application ", height=600,
                   xaxis=dict(title='Country'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="c2f478cc-4a1e-4788-aa77-6088ec98722f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2f478cc-4a1e-4788-aa77-6088ec98722f")) {                    Plotly.newPlot(                        "c2f478cc-4a1e-4788-aa77-6088ec98722f",                        [{"marker":{"color":"teal"},"name":"Users","text":[23024.0,272.0,37.0,36.0,20.0,17.0,11.0,10.0,7.0,7.0],"textposition":"auto","x":["India","United States","Canada","(not set)","United Kingdom","Singapore","Japan","Australia","Bangladesh","Germany"],"y":[23024,272,37,36,20,17,11,10,7,7],"type":"bar"},{"marker":{"color":"navy"},"name":"New users","text":[22528.0,213.0,18.0,36.0,8.0,6.0,6.0,7.0,2.0,2.0],"textposition":"auto","x":["India","United States","Canada","(no
# ...

# %% [markdown]
# ### Citiwise Report

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Town/City                  574 non-null    object
#  1   Users                      574 non-null    int64
#  2   New users                  574 non-null    int64
#  3   Engaged sessions           574 non-null    int64
#  4   Engagement rate            574 non-null    float64
#  5   Engaged sessions per user  574 non-null    float64
#  6   Average engagement time    574 non-null    float64
#  7   Event count                574 non-null    int64
#  8   Conversions                574 non-null    int64
#  9   Total revenue              574 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 45.0+ KB

# %%
df7.isnull().sum()
# Out:
# Town/City                    0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df7.duplicated().sum()
# Out:
# 0

# %%
df7.describe()
# Out:
#              Users    New users  Engaged sessions  Engagement rate  \
# count   574.000000   574.000000         574.00000       574.000000
# mean     46.203833    39.846690          71.61324         0.489662
# std     290.091708   267.115856         656.03377         0.341660
# min       0.000000     0.000000           0.00000         0.000000
# 25%       1.000000     1.000000           1.00000         0.250000
# 50%       2.000000     1.000000           2.00000         0.497547
# 75%       7.750000     5.000000           7.00000         0.724026
# max    6097.000000  5685.000000       15013.00000         1.000000
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                 574.000000               574.000000     574.000000
# mean                    0.884915                94.093768    2297.088850
# std                     0.750856               202.850678   26179.153773
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df7[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df7[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df7.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
citiwise_report_sort=df7.sort_values(by=["Users","New users"],ascending =False)
top10_citi = citiwise_report_sort.head(10)
top10_citi

bar1=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["Users"],
            text=top10_citi["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))

bar2=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["New users"],
            text=top10_citi["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="navy"))

layout = go.Layout(title="Top 10 cities attarct users", height=600,
                   xaxis=dict(title='Town/city'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="8d97c82b-966b-4449-af3c-5582a7078590" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d97c82b-966b-4449-af3c-5582a7078590")) {                    Plotly.newPlot(                        "8d97c82b-966b-4449-af3c-5582a7078590",                        [{"marker":{"color":"teal"},"name":"Users","text":[6097.0,1594.0,1038.0,983.0,897.0,809.0,798.0,767.0,749.0,745.0],"textposition":"auto","x":["Bengaluru","Patna","Hyderabad","Indore","Lucknow","Mysuru","Chennai","(not set)","Coimbatore","Guwahati"],"y":[6097,1594,1038,983,897,809,798,767,749,745],"type":"bar"},{"marker":{"color":"navy"},"name":"New users","text":[5685.0,1467.0,920.0,915.0,839.0,585.0,631.0,536.0,596.0,700.0],"textposition":"auto","x":["Bengaluru",
# ...

# %%
citiwise_report_sort=df7.sort_values(by=["Engaged sessions"],ascending =False)
top10_citi = citiwise_report_sort.head(10)
top10_citi

bar1=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["Engaged sessions"],
            text=top10_citi["Engaged sessions"],
            textposition="auto",
            name="Engaged sessions",
            marker=dict(color="teal"))

bar2=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["Event count"],
            text=top10_citi["Event count"],
            textposition="auto",
            name="Event count",
            marker=dict(color="navy"))

bar3=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["Conversions"],
            text=top10_citi["Conversions"],
            textposition="auto",
            name="Conversions",
            marker=dict(color="moccasin"))
layout = go.Layout(title="Top 10 cities by engaged session impact of Event count and conversion", height=600,
                   xaxis=dict(title='Town/city'),
                   yaxis=dict(title='Numbers count'))
fig=go.Figure(data=[bar1,bar2,bar3],layout=layout)

fig.show()
# Out:
# <div>                            <div id="efe6d824-759e-4d2f-ad89-8f48d2c48e67" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efe6d824-759e-4d2f-ad89-8f48d2c48e67")) {                    Plotly.newPlot(                        "efe6d824-759e-4d2f-ad89-8f48d2c48e67",                        [{"marker":{"color":"teal"},"name":"Engaged sessions","text":[15013.0,2127.0,1910.0,1578.0,1412.0,1241.0,1220.0,1125.0,1049.0,902.0],"textposition":"auto","x":["Bengaluru","Patna","Chennai","Hyderabad","Coimbatore","Indore","Mysuru","Lucknow","Kochi","Guwahati"],"y":[15013,2127,1910,1578,1412,1241,1220,1125,1049,902],"type":"bar"},{"marker":{"color":"navy"},"name":"Event count","text":[607200.0,38830.0,84723.0,96826.0,41275.0,21383.0,48183.0,21041.0,27187.0,16200.
# ...

# %% [markdown]
# ### Gender Report

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Gender                     3 non-null      object
#  1   Users                      3 non-null      int64
#  2   New users                  3 non-null      int64
#  3   Engaged sessions           3 non-null      int64
#  4   Engagement rate            3 non-null      float64
#  5   Engaged sessions per user  3 non-null      float64
#  6   Average engagement time    3 non-null      float64
#  7   Event count                3 non-null      int64
#  8   Conversions                3 non-null      int64
#  9   Total revenue              3 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 368.0+ bytes

# %%
df8.isnull().sum()
# Out:
# Gender                       0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df8.duplicated().sum()
# Out:
# 0

# %%
df8.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count      3.000000      3.000000          3.000000         3.000000
# mean    8434.666667   7624.000000      13835.000000         0.581626
# std     4232.258184   4458.076828       8179.714665         0.049691
# min     4944.000000   4304.000000       7877.000000         0.543091
# 25%     6081.000000   5090.500000       9172.000000         0.553584
# 50%     7218.000000   5877.000000      10467.000000         0.564077
# 75%    10180.000000   9284.000000      16814.000000         0.600893
# max    13142.000000  12691.000000      23161.000000         0.637710
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   3.000000                 3.000000       3.000000
# mean                    1.601911               258.850067  439509.666667
# std                     0.156300               161.608316  279116.984160
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df8[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df8[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df8.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
pie_chart = go.Pie(labels=df8["Gender"],
                   values=df8["Users"],
                   textinfo='label+percent',
                   textposition='inside',
                   hoverinfo='label+percent',
                   hole=0.4)
layout = go.Layout(title='User gender wise percentage ')

fig = go.Figure(data=[pie_chart], layout=layout)
fig.show()
# Out:
# <div>                            <div id="906ef330-999c-4dbc-939a-51b1e07b2835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("906ef330-999c-4dbc-939a-51b1e07b2835")) {                    Plotly.newPlot(                        "906ef330-999c-4dbc-939a-51b1e07b2835",                        [{"hole":0.4,"hoverinfo":"label+percent","labels":["unknown","male","female"],"textinfo":"label+percent","textposition":"inside","values":[13142,7218,4944],"type":"pie"}],                        {"title":{"text":"User gender wise percentage "},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{
# ...

# %%
pie_chart = go.Pie(labels=df8["Gender"],
                   values=df8["New users"],
                   textinfo='label+percent',
                   textposition='outside',
                   hoverinfo='label+percent',
                   hole=0.4)
layout = go.Layout(title='New user gender')

fig = go.Figure(data=[pie_chart], layout=layout)
fig.show()
# Out:
# <div>                            <div id="f888c553-65d0-41e5-b64a-5e6bc927d4a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f888c553-65d0-41e5-b64a-5e6bc927d4a4")) {                    Plotly.newPlot(                        "f888c553-65d0-41e5-b64a-5e6bc927d4a4",                        [{"hole":0.4,"hoverinfo":"label+percent","labels":["unknown","male","female"],"textinfo":"label+percent","textposition":"outside","values":[12691,5877,4304],"type":"pie"}],                        {"title":{"text":"New user gender"},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"l
# ...

# %%
bar1=go.Bar(x=df8["Gender"],
            y=df8["Average engagement time"]/60,
            text=df8["Average engagement time"]/60,
            textposition="auto",
            name="Avergae engament time in mins",
            marker=dict(color="navy")
            )

layout = go.Layout(title="Average time watched in mins ", height=600,
                   xaxis=dict(title='Gender'),
                   yaxis=dict(title='Average time in min'))
fig=go.Figure(data=[bar1],layout=layout)

fig.show()
# Out:
# <div>                            <div id="da360d31-e76e-477d-a1a8-8903ef407eac" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da360d31-e76e-477d-a1a8-8903ef407eac")) {                    Plotly.newPlot(                        "da360d31-e76e-477d-a1a8-8903ef407eac",                        [{"marker":{"color":"navy"},"name":"Avergae engament time in mins","text":[7.326293333333334,2.137198333333333,3.4790116666666666],"textposition":"auto","x":["unknown","male","female"],"y":[7.326293333333334,2.137198333333333,3.4790116666666666],"type":"bar"}],                        {"height":600,"title":{"text":"Average time watched in mins "},"xaxis":{"title":{"text":"Gender"}},"yaxis":{"title":{"text":"Average time in min"}},"template":{"data":{"bar":[{"error_
# ...

# %% [markdown]
# ### User by Interests

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Interests                  89 non-null     object
#  1   Users                      89 non-null     int64
#  2   New users                  89 non-null     int64
#  3   Engaged sessions           89 non-null     int64
#  4   Engagement rate            89 non-null     float64
#  5   Engaged sessions per user  89 non-null     float64
#  6   Average engagement time    89 non-null     float64
#  7   Event count                89 non-null     int64
#  8   Conversions                89 non-null     int64
#  9   Total revenue              89 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 7.1+ KB

# %%
df9.isnull().sum()
# Out:
# Interests                    0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df9.duplicated().sum()
# Out:
# 0

# %%
df9.describe()
# Out:
#               Users    New users  Engaged sessions  Engagement rate  \
# count     89.000000    89.000000         89.000000        89.000000
# mean    2411.044944  1911.280899       3373.932584         0.619191
# std     2480.482385  2059.110984       3544.597874         0.081918
# min       10.000000     3.000000          9.000000         0.450000
# 25%      107.000000    72.000000        142.000000         0.576499
# 50%     1942.000000  1566.000000       2608.000000         0.618416
# 75%     3652.000000  2872.000000       5443.000000         0.666153
# max    10950.000000  9256.000000      15680.000000         0.840000
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                  89.000000                89.000000      89.000000
# mean                    1.339172               219.531871  110565.202247
# std                     0.258550               366.821595  114195.875599
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df9[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df9[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df9.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
user_by_intrest_sort=df9.sort_values(by=["Users","New users"],ascending=False)
top10_userby_intrest=user_by_intrest_sort.head(10)
top10_userby_intrest

bar1=go.Bar(x=top10_userby_intrest["Interests"],
            y=top10_userby_intrest["Users"],
            text=top10_userby_intrest["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))


bar2=go.Bar(x=top10_userby_intrest["Interests"],
            y=top10_userby_intrest["New users"],
            text=top10_userby_intrest["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="navy"))

layout = go.Layout(title="Top 10 Intrest users and user users attract ", height=600,
                   xaxis=dict(title='Intrest'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="6dbaaad4-3d26-4879-ad8d-113ebc1e0d29" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dbaaad4-3d26-4879-ad8d-113ebc1e0d29")) {                    Plotly.newPlot(                        "6dbaaad4-3d26-4879-ad8d-113ebc1e0d29",                        [{"marker":{"color":"teal"},"name":"Users","text":[10950.0,10946.0,10934.0,8410.0,5844.0,5785.0,5488.0,5363.0,5352.0,5247.0],"textposition":"auto","x":["Shoppers","Media & Entertainment/Comics & Animation Fans","Technology/Mobile Enthusiasts","Food & Dining/Cooking Enthusiasts","Sports & Fitness/Health & Fitness Buffs","Lifestyles & Hobbies/Pet Lovers","Media & Entertainment/Music Lovers","Media & Entertainment/TV Lovers","News & Politics/Avid News Readers","Lifes
# ...

# %%
line1 = go.Scatter(x=top10_userby_intrest["Interests"],
                   y=top10_userby_intrest["Engaged sessions"],
                   mode="lines+markers",  
                   text=top10_userby_intrest["Engaged sessions"],
                   textposition="top center", 
                   name="Engaged sessions",
                   marker=dict(color="teal"))

layout = go.Layout(title="Top 10 Interests with Highest Engaged Sessions", height=600,
                   xaxis=dict(title='Interest', showline=True, showticklabels=True),
                   yaxis=dict(title='Number of Engaged Sessions', showline=True, showticklabels=True))

fig = go.Figure(data=[line1], layout=layout)

fig.show()
# Out:
# <div>                            <div id="327a360c-678a-4b1f-9bca-1fcbc2e496ff" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327a360c-678a-4b1f-9bca-1fcbc2e496ff")) {                    Plotly.newPlot(                        "327a360c-678a-4b1f-9bca-1fcbc2e496ff",                        [{"marker":{"color":"teal"},"mode":"lines+markers","name":"Engaged sessions","text":[15652.0,15680.0,15619.0,12332.0,8226.0,7786.0,8011.0,7423.0,7079.0,7441.0],"textposition":"top center","x":["Shoppers","Media & Entertainment/Comics & Animation Fans","Technology/Mobile Enthusiasts","Food & Dining/Cooking Enthusiasts","Sports & Fitness/Health & Fitness Buffs","Lifestyles & Hobbies/Pet Lovers","Media & Entertainment/Music Lovers","Media & Entertainment/TV Lovers","
# ...

# %%
line1 = go.Scatter(x=top10_userby_intrest["Interests"],
                   y=top10_userby_intrest["Conversions"],
                   mode="lines+markers",  
                   text=top10_userby_intrest["Conversions"],
                   textposition="top center",  
                   name="Conversions",
                   marker=dict(color="navy"))

layout = go.Layout(title="Top 10 Interests with Highest conversions ", height=600,
                   xaxis=dict(title='Interest', showline=True, showticklabels=True),
                   yaxis=dict(title='Number of conversions', showline=True, showticklabels=True))

fig = go.Figure(data=[line1], layout=layout)

fig.show()
# Out:
# <div>                            <div id="dd187c03-48a4-4786-a315-502b88fe00d8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd187c03-48a4-4786-a315-502b88fe00d8")) {                    Plotly.newPlot(                        "dd187c03-48a4-4786-a315-502b88fe00d8",                        [{"marker":{"color":"navy"},"mode":"lines+markers","name":"Conversions","text":[86846.0,86845.0,86742.0,73814.0,43074.0,34111.0,48962.0,38664.0,34901.0,29529.0],"textposition":"top center","x":["Shoppers","Media & Entertainment/Comics & Animation Fans","Technology/Mobile Enthusiasts","Food & Dining/Cooking Enthusiasts","Sports & Fitness/Health & Fitness Buffs","Lifestyles & Hobbies/Pet Lovers","Media & Entertainment/Music Lovers","Media & Entertainment/TV Lovers",
# ...

# %% [markdown]
# ### User by Language

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Language                   24 non-null     object
#  1   Users                      24 non-null     int64
#  2   New users                  24 non-null     int64
#  3   Engaged sessions           24 non-null     int64
#  4   Engagement rate            24 non-null     float64
#  5   Engaged sessions per user  24 non-null     float64
#  6   Average engagement time    24 non-null     float64
#  7   Event count                24 non-null     int64
#  8   Conversions                24 non-null     int64
#  9   Total revenue              24 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 2.0+ KB

# %%
df10.isnull().sum()
# Out:
# Language                     0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df10.duplicated().sum()
# Out:
# 0

# %%
df10.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count     24.000000     24.000000         24.000000        24.000000
# mean     975.916667    953.000000       1744.833333         0.535395
# std     4585.079838   4482.258359       8285.991965         0.321298
# min        0.000000      0.000000          0.000000         0.000000
# 25%        1.000000      1.000000          1.000000         0.421144
# 50%        7.000000      7.000000          7.000000         0.509036
# 75%       21.750000     20.250000         37.750000         0.677083
# max    22495.000000  21990.000000      40639.000000         1.000000
#
#        Engaged sessions per user  Average engagement time   Event count  \
# count                  24.000000                24.000000  2.400000e+01
# mean                    1.046263                65.527106  5.493871e+04
# std                     0.642224                83.316618  2.647787e+05
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df10[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df10[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df10.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
user_by_language_10 = df10.sort_values(by=["Users","New users"],ascending =False)

top_10_language=user_by_language_10.head(10)

bar1=go.Bar(x=top_10_language["Language"],
             y=top_10_language["Users"],
              text=top_10_language["Users"],
             textposition="auto",
             name="Users",
             marker=dict(color='teal'))
bar2=go.Bar(x=top_10_language["Language"],
             y=top_10_language["New users"],
                   text=top_10_language["New users"],
                   textposition="auto",
             name="New Users",
             marker=dict(color='navy'))


layout = go.Layout(title="Top 10 language prefrences by users and new users ", height=600,
                   xaxis=dict(title='Languages'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="e844e20f-96f2-4279-9245-ab091e8c3b26" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e844e20f-96f2-4279-9245-ab091e8c3b26")) {                    Plotly.newPlot(                        "e844e20f-96f2-4279-9245-ab091e8c3b26",                        [{"marker":{"color":"teal"},"name":"Users","text":[22495.0,586.0,85.0,78.0,43.0,36.0,17.0,14.0,13.0,13.0],"textposition":"auto","x":["English","Hindi","Marathi","Gujarati","Telugu","Tamil","Malayalam","Bengali","Chinese","Kannada"],"y":[22495,586,85,78,43,36,17,14,13,13],"type":"bar"},{"marker":{"color":"navy"},"name":"New Users","text":[21990.0,552.0,84.0,77.0,42.0,36.0,15.0,11.0,13.0,12.0],"textposition":"auto","x":["English","Hindi","Marathi","Gujarati","Telugu
# ...

# %% [markdown]
# ### User by age

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        7 non-null      object
#  1   Users                      7 non-null      int64
#  2   New users                  7 non-null      int64
#  3   Engaged sessions           7 non-null      int64
#  4   Engagement rate            7 non-null      float64
#  5   Engaged sessions per user  7 non-null      float64
#  6   Average engagement time    7 non-null      float64
#  7   Event count                7 non-null      int64
#  8   Conversions                7 non-null      int64
#  9   Total revenue              7 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 688.0+ bytes

# %%
df11.isnull().sum()
# Out:
# Age                          0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df11.duplicated().sum()
# Out:
# 0

# %%
df11.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count      7.000000      7.000000          7.000000         7.000000
# mean    3763.142857   3267.428571       5929.857143         0.557245
# std     4802.784277   4698.464389       8686.797289         0.065705
# min      810.000000    552.000000        881.000000         0.504780
# 25%     1302.500000    882.000000       1486.000000         0.514917
# 50%     1422.000000   1081.000000       1640.000000         0.539829
# 75%     3601.000000   2919.500000       5520.000000         0.565480
# max    14303.000000  13636.000000      24976.000000         0.695308
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   7.000000                 7.000000       7.000000
# mean                    1.323049               151.275793  188361.285714
# std                     0.281679               137.114289  296206.859168
# ...

# %%
numerical_columns = ['Users','New users','Engaged sessions','Engagement rate','Engaged sessions per user','Average engagement time','Event count','Conversions']

for column in numerical_columns:
    plt.hist(df11[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df11[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df11.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
bar1 = go.Bar(x=df11['Age'],
              y=df11["Users"],
              text=df11["Users"],
              textposition="auto",
              name="Users",
              marker=dict(color='teal'))

bar2 = go.Bar(x=df11['Age'],
              y=df11["New users"],
              text=df11["New users"],
              textposition="auto",
              name="New Users",
              marker=dict(color='navy'))


layout = go.Layout(title="Age wise users and new users", height=600,
                   xaxis=dict(title='Age Catergory'),
                   yaxis=dict(title='Number of unsers and new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="80e29445-3f6a-460b-aaf1-b49c72049934" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80e29445-3f6a-460b-aaf1-b49c72049934")) {                    Plotly.newPlot(                        "80e29445-3f6a-460b-aaf1-b49c72049934",                        [{"marker":{"color":"teal"},"name":"Users","text":[14303.0,4282.0,2920.0,1422.0,1403.0,1202.0,810.0],"textposition":"auto","x":["unknown","18-24","25-34","65+","55-64","35-44","45-54"],"y":[14303,4282,2920,1422,1403,1202,810],"type":"bar"},{"marker":{"color":"navy"},"name":"New Users","text":[13636.0,3678.0,2161.0,1081.0,979.0,785.0,552.0],"textposition":"auto","x":["unknown","18-24","25-34","65+","55-64","35-44","45-54"],"y":[13636,3678,2161,1081,979,785,552],"ty
# ...

# %%
engaged_sessions=go.Bar(x=df11["Age"],
             y=df11["Engaged sessions"],
              text=df11["Engaged sessions"],
             textposition="auto",
             name="Engaged Sessions",
             marker=dict(color='teal'))

event_count=go.Bar(x=df11["Age"],
             y=df11["Event count"],
                   text=df11["Event count"],
                   textposition="auto",
             name="Event counts",
             marker=dict(color='navy'))


layout = go.Layout(title="Age group by sessions organished and event happens ", height=600,
                   xaxis=dict(title='Age Catergory'),
                   yaxis=dict(title='Number of sessions and event happens'))
fig=go.Figure(data=[engaged_sessions,event_count],layout=layout)

fig.show()
# Out:
# <div>                            <div id="0b1b850f-4c4a-46a2-b385-862755bfb26e" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b1b850f-4c4a-46a2-b385-862755bfb26e")) {                    Plotly.newPlot(                        "0b1b850f-4c4a-46a2-b385-862755bfb26e",                        [{"marker":{"color":"teal"},"name":"Engaged Sessions","text":[24976.0,7291.0,3749.0,1640.0,1552.0,1420.0,881.0],"textposition":"auto","x":["unknown","18-24","25-34","65+","55-64","35-44","45-54"],"y":[24976,7291,3749,1640,1552,1420,881],"type":"bar"},{"marker":{"color":"navy"},"name":"Event counts","text":[817501.0,309328.0,90074.0,24780.0,25169.0,33016.0,18661.0],"textposition":"auto","x":["unknown","18-24","25-34","65+","55-64","35-44","45-54"],"y":[817501,30932
# ...

# %% [markdown]
# ### Google Ads Report

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Session Google Ads campaign  15 non-null     object
#  1   Users                        15 non-null     int64
#  2   Sessions                     15 non-null     int64
#  3   Engaged sessions             15 non-null     int64
#  4   Google Ads clicks            15 non-null     int64
#  5   Google Ads cost              15 non-null     float64
#  6   Google Ads cost per click    15 non-null     float64
#  7   Conversions                  15 non-null     int64
#  8   Cost per conversion          15 non-null     float64
#  9   Event count                  15 non-null     int64
#  10  Total revenue                15 non-null     int64
#  11  Return on ad spend           15 non-null     int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1.5+ KB

# %%
df12.isnull().sum()
# Out:
# Session Google Ads campaign    0
# Users                          0
# Sessions                       0
# Engaged sessions               0
# Google Ads clicks              0
# Google Ads cost                0
# Google Ads cost per click      0
# Conversions                    0
# Cost per conversion            0
# Event count                    0
# Total revenue                  0
# Return on ad spend             0
# dtype: int64

# %%
df12.duplicated().sum()
# Out:
# 0

# %%
df12.describe()
# Out:
#              Users      Sessions  Engaged sessions  Google Ads clicks  \
# count    15.000000     15.000000         15.000000          15.000000
# mean    666.200000   1274.133333        756.666667       17021.200000
# std    1348.253696   2721.749093       1558.314184       36934.069186
# min       2.000000      5.000000          5.000000          14.000000
# 25%      62.000000    100.500000         65.500000        1778.500000
# 50%     370.000000    610.000000        425.000000        4475.000000
# 75%     621.000000    971.000000        654.500000       14202.000000
# max    5429.000000  10936.000000       6276.000000      147100.000000
#
#        Google Ads cost  Google Ads cost per click   Conversions  \
# count        15.000000                  15.000000     15.000000
# mean      20089.196451                   1.237784   1421.533333
# std       44773.537357                   0.635640   3047.587755
# min          16.623960                   0.485200      5.000000
# ...

# %%
numerical_columns = ['Users','Sessions','Engaged sessions','Google Ads clicks','Google Ads cost','Google Ads cost per click','Conversions','Cost per conversion','Event count']

for column in numerical_columns:
    plt.hist(df12[column], bins=20)  
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in numerical_columns:
    sns.boxplot(x=df12[column])
    plt.xlabel(column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
correlation_matrix = df12.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
bar1 = go.Bar(x=df12['Session Google Ads campaign'],
              y=df12["Sessions"],
              text=df12["Sessions"],
              textposition="auto",
              name="Sessions",
              marker=dict(color='navy'))

bar2 = go.Bar(x=df12['Session Google Ads campaign'],
              y=df12["Engaged sessions"],
              text=df12["Engaged sessions"],
              textposition="auto",
              name="Engaged sessions")

layout = go.Layout(title="Number of session generated and actively engaged google Ads campaign", height=800)

fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="7aafda28-dbc4-42c7-86c4-e507bbe21c00" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aafda28-dbc4-42c7-86c4-e507bbe21c00")) {                    Plotly.newPlot(                        "7aafda28-dbc4-42c7-86c4-e507bbe21c00",                        [{"marker":{"color":"navy"},"name":"Sessions","text":[10936.0,1655.0,1332.0,976.0,966.0,945.0,742.0,610.0,432.0,188.0,124.0,77.0,75.0,49.0,5.0],"textposition":"auto","x":["App Installation for May --Shahid","App Install-States-A200Inst-20Jun22","App Install-States-B100Installs-22Jun22","App Install for April -- Shahid","Video-AppInstall-PS-Internships-11Jul22","App promotion-App-3","App Instal-States-B200 &A100Inst-22Jun22","App Install-1to5NC-StateA200-07Jul22","
# ...

# %%
line1 = go.Scatter(x=df12["Session Google Ads campaign"],
                   y=df12["Google Ads cost"],
                   mode="lines+markers",
                   text=df12["Google Ads cost"],
                   marker=dict(color="teal"),
                   name="Google Ads cost")

line2 = go.Scatter(x=df12["Session Google Ads campaign"],
                   y=df12["Conversions"],
                   mode="lines + markers",
                   text=df12["Conversions"],
                   marker=dict(color="salmon"),
                   name="Conversions")

layout = go.Layout(title="Cost invested in google add againsts conversion", height=600,
                   xaxis=dict(title='sessions google ads campaign'),
                   yaxis=dict(title='Amount invested and number of conversion'))
fig=go.Figure(data=[line1,line2],layout=layout)

fig.show()
# Out:
# <div>                            <div id="1c41c472-e5e4-43eb-9869-c157090bc3a0" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c41c472-e5e4-43eb-9869-c157090bc3a0")) {                    Plotly.newPlot(                        "1c41c472-e5e4-43eb-9869-c157090bc3a0",                        [{"marker":{"color":"teal"},"mode":"lines+markers","name":"Google Ads cost","text":[179175.0,24309.13,22374.58,20525.18,6377.833,12084.04,11993.01,8839.723,9204.696,1535.27,1903.418,1263.625,935.7227,800.0951,16.62396],"x":["App Installation for May --Shahid","App Install-States-A200Inst-20Jun22","App Install-States-B100Installs-22Jun22","App Install for April -- Shahid","Video-AppInstall-PS-Internships-11Jul22","App promotion-App-3","App Instal-States-B200 &A100I
# ...
